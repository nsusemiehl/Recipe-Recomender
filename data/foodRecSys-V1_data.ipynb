# %%
import pandas as pd
import ast

# %%
recipe = pd.read_csv('/Users/cj/Desktop/GT/CSE-6242/Project/database/core-data_recipe.csv')
recipe.head()
# Out:
#    recipe_id                              recipe_name  \
# 0     240488        Pork Loin, Apples, and Sauerkraut
# 1     218939         Foolproof Rosemary Chicken Wings
# 2      87211                    Chicken Pesto Paninis
# 3     245714                       Potato Bacon Pizza
# 4     218545  Latin-Inspired Spicy Cream Chicken Stew
#
#                                            image_url  \
# 0  https://images.media-allrecipes.com/userphotos...
# 1  https://images.media-allrecipes.com/userphotos...
# 2  https://images.media-allrecipes.com/userphotos...
# 3  https://images.media-allrecipes.com/userphotos...
# 4  https://images.media-allrecipes.com/userphotos...
#
#                                          ingredients  \
# 0  sauerkraut drained^Granny Smith apples sliced^...
# 1  chicken wings^sprigs rosemary^head garlic^oliv...
# 2  focaccia bread quartered^prepared basil pesto^...
# 3  red potatoes^strips bacon^Sauce:^heavy whippin...
# 4  skinless boneless chicken breast halves^diced ...
#
#                                   cooking_directions  \
# 0  {'directions': u'Prep\n15 m\nCook\n2 h 30 m\nR...
# 1  {'directions': u"Prep\n20 m\nCook\n40 m\nReady...
# 2  {'directions': u'Prep\n15 m\nCook\n5 m\nReady ...
# 3  {'directions': u'Prep\n20 m\nCook\n45 m\nReady...
# 4  {'directions': u'Prep\n10 m\nCook\n8 h 15 m\nR...
#
#                                           nutritions
# 0  {u'niacin': {u'hasCompleteData': False, u'name...
# 1  {u'niacin': {u'hasCompleteData': True, u'name'...
# 2  {u'niacin': {u'hasCompleteData': True, u'name'...
# 3  {u'niacin': {u'hasCompleteData': True, u'name'...
# 4  {u'niacin': {u'hasCompleteData': False, u'name...

# %%
nutritions_dict = []

for row in recipe.nutritions:
    nutritions_dict.append(ast.literal_eval(row))

# %%
len(list(nutritions_dict[0].keys()))

print(len(nutritions_dict))
# Out:
# 45630

# %%
nutritions_keys = []

for i in range(len(nutritions_dict)):
    for key in list(nutritions_dict[i].keys()):
        if key in nutritions_keys:
            pass
        else:
            nutritions_keys.append(key)

len(nutritions_keys)
# Out:
# 20

# %%
nutritions_keys
# Out:
# ['niacin',
#  'sugars',
#  'sodium',
#  'carbohydrates',
#  'vitaminB6',
#  'calories',
#  'thiamin',
#  'fat',
#  'folate',
#  'caloriesFromFat',
#  'calcium',
#  'fiber',
#  'magnesium',
#  'iron',
#  'cholesterol',
#  'protein',
#  'vitaminA',
#  'potassium',
#  'saturatedFat',
#  'vitaminC']

# %%
niacin_list = []
sugars_list = []
sodium_list = []
carbohydrates_list = []
vitaminB6_list = []
calories_list = []
thiamin_list = []
fat_list = []
folate_list = []
caloriesFromFat_list = []
calcium_list = []
fiber_list = []
magnesium_list = []
iron_list = []
cholesterol_list = []
protein_list = []
vitaminA_list = []
potassium_list = []
saturatedFat_list = []
vitaminC_list = []

for i in range(len(nutritions_dict)):
    niacin_list.append(nutritions_dict[i]['niacin']['percentDailyValue'])
    sugars_list.append(nutritions_dict[i]['sugars']['percentDailyValue'])
    sodium_list.append(nutritions_dict[i]['sodium']['percentDailyValue'])
    carbohydrates_list.append(nutritions_dict[i]['carbohydrates']['percentDailyValue'])
    vitaminB6_list.append(nutritions_dict[i]['vitaminB6']['percentDailyValue'])
    calories_list.append(nutritions_dict[i]['calories']['percentDailyValue'])
    thiamin_list.append(nutritions_dict[i]['thiamin']['percentDailyValue'])
    fat_list.append(nutritions_dict[i]['fat']['percentDailyValue'])
    folate_list.append(nutritions_dict[i]['folate']['percentDailyValue'])
    caloriesFromFat_list.append(nutritions_dict[i]['caloriesFromFat']['percentDailyValue'])
    calcium_list.append(nutritions_dict[i]['calcium']['percentDailyValue'])
    fiber_list.append(nutritions_dict[i]['fiber']['percentDailyValue'])
    magnesium_list.append(nutritions_dict[i]['magnesium']['percentDailyValue'])
    iron_list.append(nutritions_dict[i]['iron']['percentDailyValue'])
    cholesterol_list.append(nutritions_dict[i]['cholesterol']['percentDailyValue'])
    protein_list.append(nutritions_dict[i]['protein']['percentDailyValue'])
    vitaminA_list.append(nutritions_dict[i]['vitaminA']['percentDailyValue'])
    potassium_list.append(nutritions_dict[i]['potassium']['percentDailyValue'])
    saturatedFat_list.append(nutritions_dict[i]['saturatedFat']['percentDailyValue'])
    vitaminC_list.append(nutritions_dict[i]['vitaminC']['percentDailyValue'])

# %%
nutritions_data = {'niacin': niacin_list, 'sugars': sugars_list, 'sodium': sodium_list, 
        'carbohydrates': carbohydrates_list, 'vitaminB6': vitaminB6_list, 'calories': calories_list,
        'thiamin': thiamin_list, 'fat': fat_list, 'folate': folate_list,
        'caloriesFromFat': caloriesFromFat_list, 'calcium': calcium_list, 'fiber': fiber_list, 
        'magnesium': magnesium_list, 'iron': iron_list, 'chalesterol': cholesterol_list,
        'protein': protein_list, 'vitaminA': vitaminA_list, 'potassium': potassium_list,
        'saturatedFat': saturatedFat_list, 'vitaminC': vitaminC_list}

nutritions_df = pd.DataFrame(nutritions_data)
nutritions_df.index = recipe['recipe_id']
nutritions_df.head()
# Out:
#           niacin sugars sodium carbohydrates vitaminB6 calories thiamin fat  \
# recipe_id
# 240488       120      0    104            10        83       19      84  18
# 218939        77      0     31             2        35       17       6  36
# 87211        102      0     43            20        17       32       3  45
# 245714        23      0      8             5         3        8      17  12
# 218545        80      0     52            12        18       17      16  12
#
#           folate caloriesFromFat calcium fiber magnesium iron chalesterol  \
# recipe_id
# 240488        47               -      17    41        29   66          33
# 218939         4               -       8     4         9   17          24
# 87211        130               -      66    18        23   50          20
# 245714        27               -      17     3         4   10           7
# 218545        45               -      14    32        19   63          21
#
#           protein vitaminA potassium saturatedFat vitaminC
# recipe_id
# 240488         73        1        31           18       88
# 218939         48        7         7           28        9
# 87211          65       12        10           55       30
# 245714         14        3         3           20        2
# 218545         52       32        19           19       23

# %%
cooking_directions_dict = []

for row in recipe['cooking_directions']:
    cooking_directions_dict.append(ast.literal_eval(row))
    
cooking_directions_dict[0]
# Out:
# {'directions': 'Prep\n15 m\nCook\n2 h 30 m\nReady In\n2 h 45 m\nPreheat oven to 325 degrees F (165 degrees C).\nMix sauerkraut, apples, onion, and caraway seeds in a large roasting pan. Stir 1/4 cup apple cider and brown sugar together in a separate bowl; pour over sauerkraut mixture.\nStir Thai seasoning, salt, garlic powder, and black pepper together in a small bowl; rub onto the top and bottom of the roast.\nMake an indentation in the center of the sauerkraut mixture and place the seasoned roast in the indentation. Pour the remaining apple cider around the roast.\nBake in the preheated oven for 1 hour; baste roast with juices. Continue baking roast, basting every 30 minutes, until cooked through, 2 1/2 to 3 hours. An instant-read thermometer inserted into the center should read at least 145 degrees F (63 degrees C).'}

# %%
list(cooking_directions_dict[0].values())[0]
list(cooking_directions_dict[0].values())[0].split('\n')
# Out:
# ['Prep',
#  '15 m',
#  'Cook',
#  '2 h 30 m',
#  'Ready In',
#  '2 h 45 m',
#  'Preheat oven to 325 degrees F (165 degrees C).',
#  'Mix sauerkraut, apples, onion, and caraway seeds in a large roasting pan. Stir 1/4 cup apple cider and brown sugar together in a separate bowl; pour over sauerkraut mixture.',
#  'Stir Thai seasoning, salt, garlic powder, and black pepper together in a small bowl; rub onto the top and bottom of the roast.',
#  'Make an indentation in the center of the sauerkraut mixture and place the seasoned roast in the indentation. Pour the remaining apple cider around the roast.',
#  'Bake in the preheated oven for 1 hour; baste roast with juices. Continue baking roast, basting every 30 minutes, until cooked through, 2 1/2 to 3 hours. An instant-read thermometer inserted into the center should read at least 145 degrees F (63 degrees C).']

# %%
prep_list = []
cook_list = []
ready_in_list = []
directions_list = []
directions_in_list_form = 0

for i in range(len(cooking_directions_dict)):
    temp = list(cooking_directions_dict[i].values())[0].split('\n')
    try:
        if temp[0] == 'Prep':
            if temp[2] == 'Cook':
                prep_list.append(temp[1])
                cook_list.append(temp[3])
                ready_in_list.append(temp[5])
                directions_list.append(' '.join(temp[6:]))
            elif temp[2] == 'Ready In':
                prep_list.append(temp[1])
                cook_list.append('NaN')
                ready_in_list.append(temp[3])
                directions_list.append(' '.join(temp[4:]))
        elif temp[0] == 'Cook':
            prep_list.append('NaN')
            if temp[2] == 'Ready In':
                cook_list.append(temp[1])
                ready_in_list.append(temp[3])
                directions_list.append(' '.join(temp[4:]))
            else:
                cook_list.append(temp[1])
                ready_in_list.append('NaN')
                directions_list.append(' '.join(temp[2:]))
        elif temp[0] == 'Ready In':
            prep_list.append('NaN')
            cook_list.append('NaN')
            ready_in_list.append(temp[1])
            directions_list.append(' '.join(temp[2:]))
        else:
            prep_list.append('NaN')
            cook_list.append('NaN')
            ready_in_list.append('NaN')
            directions_list.append(' '.join(temp))
            directions_in_list_form += 1
    except:
        prep_list.append('NaN')
        cook_list.append('NaN')
        ready_in_list.append('NaN')
        directions_list.append('NaN')

cooking_directions_data = {'prep': prep_list, 'cook': cook_list, 'ready_in': ready_in_list, 'directions': directions_list}

cooking_directions_df = pd.DataFrame(cooking_directions_data)
cooking_directions_df.index = recipe['recipe_id']

print(directions_in_list_form)
cooking_directions_df.head()
# Out:
# 4865
#            prep      cook  ready_in  \
# recipe_id
# 240488     15 m  2 h 30 m  2 h 45 m
# 218939     20 m      40 m       1 h
# 87211      15 m       5 m      20 m
# 245714     20 m      45 m  1 h 10 m
# 218545     10 m  8 h 15 m  8 h 25 m
#
#                                                   directions
# recipe_id
# 240488     Preheat oven to 325 degrees F (165 degrees C)....
# 218939     Preheat an oven to 350 degrees F (175 degrees ...
# 87211      Preheat a panini grill. Slice each quarter of ...
# 245714     Place potato slices in a deep skillet and cove...
# 218545     Place the chicken breasts into the bottom of a...

# %%
null = cooking_directions_df['cook'] == 'NaN'
cooking_directions_df[null]
# Out:
#            prep cook  ready_in  \
# recipe_id
# 25930      10 m  NaN  1 h 10 m
# 8987        NaN  NaN       NaN
# 214631     10 m  NaN      30 m
# 8657        NaN  NaN       NaN
# 9035        NaN  NaN       NaN
# ...         ...  ...       ...
# 159647      5 m  NaN       5 m
# 238024     20 m  NaN  3 h 20 m
# 222886      5 m  NaN       5 m
# 25650      15 m  NaN      15 m
# 23544       1 m  NaN       1 m
#
#                                                   directions
# recipe_id
# 25930      In a medium bowl, combine the chicken, mayonna...
# 8987       Preheat oven to 350 degrees F (175 degrees C)....
# 214631     Stir the chicken, mayonnaise, celery, pine nut...
# 8657       In a large bowl toss together the chicken, rai...
# 9035       Preheat oven to 425 degrees F (220 degrees C)....
# ...                                                      ...
# 159647     Pour the vodka, triple sec, cranberry juice, a...
# 238024     Chop green bell pepper, red bell pepper, onion...
# 222886     Combine tequila, vodka, rum, gin, and raspberr...
# 25650      Sprinkle raisins with brandy and set aside. In...
# 23544      In a blender, combine peaches, ice cream, soy ...
#
# [11903 rows x 4 columns]

# %%
# Separating the ingredients
ingredients_list = []
temp=[]
for row in range(len(recipe.ingredients)):
    temp = recipe.ingredients[row].split("^")
    ingredients_list.append(temp)
    temp = []

#  Cleaning the ingredients
ingredients_list_clean = []  
num_ingredients_list = []
for i in range(len(ingredients_list)):
    for j in range(len(ingredients_list[i])):
        if ":" not in ingredients_list[i][j]:
            temp.append(ingredients_list[i][j])
    ingredients_list_clean.append(temp)
    num_ingredients_list.append(len(temp))
    temp = []


ingredients_list_clean[0]
#num_ingredients_list[0]
# Out:
# ['sauerkraut drained',
#  'Granny Smith apples sliced',
#  'large onion',
#  'caraway seeds',
#  'apple cider divided',
#  'brown sugar',
#  'Thai seasoning',
#  'salt',
#  'garlic powder',
#  'ground black pepper',
#  'boneless pork loin roast']

# %%
ingredients_dict = {"ingredients":ingredients_list_clean,"number_ingredients":num_ingredients_list}
ingredients_df = pd.DataFrame(ingredients_dict)
ingredients_df.index= recipe["recipe_id"]
ingredients_df.head()
# Out:
#                                                  ingredients  \
# recipe_id
# 240488     [sauerkraut drained, Granny Smith apples slice...
# 218939     [chicken wings, sprigs rosemary, head garlic, ...
# 87211      [focaccia bread quartered, prepared basil pest...
# 245714     [red potatoes, strips bacon, heavy whipping cr...
# 218545     [skinless boneless chicken breast halves, dice...
#
#            number_ingredients
# recipe_id
# 240488                     11
# 218939                      6
# 87211                       6
# 245714                     12
# 218545                     11

# %%
recipe_1 = recipe.drop(["ingredients","cooking_directions","image_url","cooking_directions","nutritions"],axis = 1)

recipe_clean = pd.merge(recipe_1, ingredients_df, on = "recipe_id")
recipe_clean = pd.merge(recipe_clean, cooking_directions_df, on = "recipe_id")
recipe_clean = pd.merge(recipe_clean, nutritions_df, on = "recipe_id")

recipe_clean.head()
# Out:
#    recipe_id                              recipe_name  \
# 0     240488        Pork Loin, Apples, and Sauerkraut
# 1     218939         Foolproof Rosemary Chicken Wings
# 2      87211                    Chicken Pesto Paninis
# 3     245714                       Potato Bacon Pizza
# 4     218545  Latin-Inspired Spicy Cream Chicken Stew
#
#                                          ingredients  number_ingredients  \
# 0  [sauerkraut drained, Granny Smith apples slice...                  11
# 1  [chicken wings, sprigs rosemary, head garlic, ...                   6
# 2  [focaccia bread quartered, prepared basil pest...                   6
# 3  [red potatoes, strips bacon, heavy whipping cr...                  12
# 4  [skinless boneless chicken breast halves, dice...                  11
#
#    prep      cook  ready_in  \
# 0  15 m  2 h 30 m  2 h 45 m
# 1  20 m      40 m       1 h
# 2  15 m       5 m      20 m
# 3  20 m      45 m  1 h 10 m
# 4  10 m  8 h 15 m  8 h 25 m
#
#                                           directions niacin sugars  ...  \
# 0  Preheat oven to 325 degrees F (165 degrees C)....    120      0  ...
# 1  Preheat an oven to 350 degrees F (175 degrees ...     77      0  ...
# 2  Preheat a panini grill. Slice each quarter of ...    102      0  ...
# 3  Place potato slices in a deep skillet and cove...     23      0  ...
# 4  Place the chicken breasts into the bottom of a...     80      0  ...
#
#   calcium fiber magnesium iron chalesterol protein vitaminA potassium  \
# 0      17    41        29   66          33      73        1        31
# 1       8     4         9   17          24      48        7         7
# 2      66    18        23   50          20      65       12        10
# 3      17     3         4   10           7      14        3         3
# 4      14    32        19   63          21      52       32        19
#
#   saturatedFat vitaminC
# 0           18       88
# 1           28        9
# 2           55       30
# 3           20        2
# 4           19       23
#
# [5 rows x 28 columns]

# %%
recipe_clean.to_csv("recipe_clean.csv")
